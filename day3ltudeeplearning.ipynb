# %%
import tensorflow as tf
import time

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#   5472256/170498071 ━━━━━━━━━━━━━━━━━━━━ 38:19 14us/step

# %%
import time

start = time.time()

history = model.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.2949 - loss: 1.9399 - val_accuracy: 0.3226 - val_loss: 1.8550
# Epoch 2/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3687 - loss: 1.7665 - val_accuracy: 0.3716 - val_loss: 1.7455
# Epoch 3/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.3906 - loss: 1.7086 - val_accuracy: 0.3752 - val_loss: 1.7260
# Epoch 4/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4042 - loss: 1.6713 - val_accuracy: 0.4088 - val_loss: 1.6726
# Epoch 5/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4136 - loss: 1.6423 - val_accuracy: 0.4124 - val_loss: 1.6454
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4187 - loss: 1.6346
# Test Loss: 1.6346471309661865
# Test Accuracy: 0.4187000095844269
# Elapsed: 45.568838119506836
