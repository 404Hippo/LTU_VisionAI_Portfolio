# %% [markdown]
# # DAY 3 — WEDNESDAY — Student Lab Notebook
# ## Neural Networks & Deep Learning
#
# **How this notebook works:** every section has a working example — run it first. Then work through each numbered **STEP** in order with your pair; both people should be able to explain every line before moving on. Finished early? Try the **BONUS** challenges.

# %% [markdown]
# ---
# ## Lab: Build & Train Your First Neural Network

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# *Work in the Day 3 notebook, on the MNIST handwritten digits dataset.*

# %% [markdown]
# ### Step 1
# Build the Sequential model exactly as shown, using the digits dataset. Compile it.

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ...

# %% [markdown]
# ### Step 2
# Train it with model.fit() for 5 epochs. Print the final test accuracy — baseline should land near 97%.

# %%
import time

start = time.time()

history = model.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9068 - loss: 0.3178 - val_accuracy: 0.9622 - val_loss: 0.1338
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9594 - loss: 0.1387 - val_accuracy: 0.9713 - val_loss: 0.0990
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9689 - loss: 0.1013 - val_accuracy: 0.9742 - val_loss: 0.0875
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9759 - loss: 0.0786 - val_accuracy: 0.9732 - val_loss: 0.0915
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9799 - loss: 0.0663 - val_accuracy: 0.9728 - val_loss: 0.0903
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9714 - loss: 0.0968
# Test Loss: 0.09679988026618958
# Test Accuracy: 0.9714000225067139
# Elapsed: 18.452701330184937

# %% [markdown]
# ### Step 3
# Change the first Dense layer from 64 neurons to 16, retrain, and record the new accuracy.

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 16)             │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,434 (52.48 KB)
#  Trainable params: 13,434 (52.48 KB)
# ...

# %%
import time

start = time.time()

history2 = model2.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model2.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8742 - loss: 0.4267 - val_accuracy: 0.9383 - val_loss: 0.2066
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9348 - loss: 0.2272 - val_accuracy: 0.9477 - val_loss: 0.1800
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9444 - loss: 0.1895 - val_accuracy: 0.9580 - val_loss: 0.1560
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9505 - loss: 0.1675 - val_accuracy: 0.9607 - val_loss: 0.1457
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9553 - loss: 0.1516 - val_accuracy: 0.9580 - val_loss: 0.1506
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9513 - loss: 0.1671
# Test Loss: 0.16712917387485504
# Test Accuracy: 0.9513000249862671
# Elapsed: 14.096572399139404

# %% [markdown]
# ### Step 4
# Change it again to 256 neurons, retrain, and record accuracy and roughly how much longer training took.

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model3 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model3.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         8,224 │
# ...

# %%
import time

start = time.time()

history3 = model3.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model3.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9301 - loss: 0.2395 - val_accuracy: 0.9643 - val_loss: 0.1198
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9688 - loss: 0.1003 - val_accuracy: 0.9762 - val_loss: 0.0747
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9788 - loss: 0.0671 - val_accuracy: 0.9772 - val_loss: 0.0741
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9853 - loss: 0.0479 - val_accuracy: 0.9760 - val_loss: 0.0834
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9869 - loss: 0.0402 - val_accuracy: 0.9785 - val_loss: 0.0740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9763 - loss: 0.0823
# Test Loss: 0.08230368047952652
# Test Accuracy: 0.9763000011444092
# Elapsed: 29.580383777618408

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Use the drawing cell at the end of the notebook to draw your own digit with the mouse and watch the live prediction.
#
# **Bonus 2:** Add a third Dense(32, activation='relu') layer between the existing two and see if accuracy improves.

# %%
# YOUR TURN — Bonus 1

# %%
# YOUR TURN — Bonus 2

# %% [markdown]
# ---
# ## Lab: Plot & Interpret Training Curves

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
history = model.fit(X_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9836 - loss: 0.0529 - val_accuracy: 0.9750 - val_loss: 0.0849
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9847 - loss: 0.0463 - val_accuracy: 0.9773 - val_loss: 0.0900
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9871 - loss: 0.0401 - val_accuracy: 0.9777 - val_loss: 0.0824
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9891 - loss: 0.0339 - val_accuracy: 0.9748 - val_loss: 0.0940
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9901 - loss: 0.0297 - val_accuracy: 0.9763 - val_loss: 0.0890
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9911 - loss: 0.0276 - val_accuracy: 0.9775 - val_loss: 0.0966
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9923 - loss: 0.0226 - val_accuracy: 0.9782 - val_loss: 0.0958
# Epoch 8/10
# ...

# %% [markdown]
# *Work in the Day 3 notebook, continuing from your morning model.*

# %% [markdown]
# ### Step 1
# Retrain your model with validation_split=0.1 and epochs=15, saving the result as history.

# %%
history = model.fit(X_train, y_train, epochs=15, validation_split=0.1)
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9949 - loss: 0.0156 - val_accuracy: 0.9762 - val_loss: 0.1109
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9945 - loss: 0.0162 - val_accuracy: 0.9785 - val_loss: 0.1137
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9957 - loss: 0.0134 - val_accuracy: 0.9780 - val_loss: 0.1047
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9742 - val_loss: 0.1387
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9961 - loss: 0.0124 - val_accuracy: 0.9775 - val_loss: 0.1174
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9958 - loss: 0.0123 - val_accuracy: 0.9723 - val_loss: 0.1479
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9780 - val_loss: 0.1227
# Epoch 8/15
# ...

# %% [markdown]
# ### Step 2
# Plot history.history['accuracy'] and history.history['val_accuracy'] on the same chart.

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label = 'train accuracy')
plt.plot(history.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Step 3
# In one sentence, state whether your plot shows signs of overfitting, and how you can tell.

# %%
# it has a little bit overfitting like train accuracy is more consistent and higher than val accuracy and still improving each epoch

# %% [markdown]
# ### Step 4
# Retrain with epochs=30 instead. Does overfitting appear more clearly, less clearly, or about the same?

# %%
history = model.fit(X_train, y_train, epochs=30, validation_split=0.1)
# Out:
# Epoch 1/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9765 - val_loss: 0.1368
# Epoch 2/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9969 - loss: 0.0089 - val_accuracy: 0.9768 - val_loss: 0.1411
# Epoch 3/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9969 - loss: 0.0090 - val_accuracy: 0.9778 - val_loss: 0.1384
# Epoch 4/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9760 - val_loss: 0.1430
# Epoch 5/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9777 - val_loss: 0.1473
# Epoch 6/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9788 - val_loss: 0.1504
# Epoch 7/30
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9780 - val_loss: 0.1486
# Epoch 8/30
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label = 'train accuracy')
plt.plot(history.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
# this is actually more overfitting like after epoch 18 it gets cooked.

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Plot loss and val_loss the same way. Does the loss chart tell the same story as the accuracy chart?

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val loss')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# yes it does tell same story. validation set loss is much more variable proving that it is overfitting overtime compared the the smooth training set loss

# %% [markdown]
# ---
# ## Lab: Systematic Architecture Tuning

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
# Compare architectures systematically
for units in [16, 128, 512]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16 neurons -> 0.9394000172615051
# 128 neurons -> 0.9750000238418579
# 512 neurons -> 0.975600004196167

# %% [markdown]
# *Work in the Day 3 notebook, continuing with the MNIST digits model.*

# %% [markdown]
# ### Step 1
# Record your baseline architecture and its accuracy in a simple table (architecture → accuracy).

# %%
# Compare architectures systematically
for units in [16, 128, 512]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 16 neurons -> 0.9417999982833862
# 128 neurons -> 0.9745000004768372
# 512 neurons -> 0.9771000146865845

# %% [markdown]
# ### Step 2
# Change ONLY the neuron count (try 16, then 64, then 256) and log each result.

# %%
# Compare architectures systematically
for units in [16, 64, 256]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 16 neurons -> 0.9455999732017517
# 64 neurons -> 0.9670000076293945
# 256 neurons -> 0.9757000207901001

# %%
# Compare architectures systematically
for units in [16, 64, 128]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 16 neurons -> 0.9466999769210815
# 64 neurons -> 0.9675999879837036
# 128 neurons -> 0.970300018787384

# %%
# Compare architectures systematically
for units in [16, 32, 64]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 16 neurons -> 0.9408000111579895
# 32 neurons -> 0.9592000246047974
# 64 neurons -> 0.9678999781608582

# %%
# Compare architectures systematically
for units in [10, 16, 32]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 10 neurons -> 0.9251999855041504
# 16 neurons -> 0.9398000240325928
# 32 neurons -> 0.9609000086784363

# %% [markdown]
# ### Step 3
# Reset to your best neuron count. Now add a third layer and log the result. Then remove it and log again.

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model4 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model4.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model4.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_15 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 10)             │         5,130 │
# ...

# %%
import time

start = time.time()

history4 = model4.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model4.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9364 - loss: 0.2157 - val_accuracy: 0.9733 - val_loss: 0.0906
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9741 - loss: 0.0850 - val_accuracy: 0.9755 - val_loss: 0.0808
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9827 - loss: 0.0555 - val_accuracy: 0.9805 - val_loss: 0.0701
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9876 - loss: 0.0379 - val_accuracy: 0.9772 - val_loss: 0.0739
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9902 - loss: 0.0295 - val_accuracy: 0.9787 - val_loss: 0.0777
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9792 - loss: 0.0721
# Test Loss: 0.07214431464672089
# Test Accuracy: 0.979200005531311
# Elapsed: 45.14827346801758

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model5 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model5.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model5.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_16 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 256)            │       131,328 │
# ...

# %%
import time

start = time.time()

history5 = model5.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model5.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9392 - loss: 0.1997 - val_accuracy: 0.9710 - val_loss: 0.0922
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9739 - loss: 0.0840 - val_accuracy: 0.9772 - val_loss: 0.0802
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9821 - loss: 0.0569 - val_accuracy: 0.9775 - val_loss: 0.0751
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9863 - loss: 0.0426 - val_accuracy: 0.9725 - val_loss: 0.0989
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9892 - loss: 0.0344 - val_accuracy: 0.9777 - val_loss: 0.0877
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9764 - loss: 0.0775
# Test Loss: 0.07754910737276077
# Test Accuracy: 0.9764000177383423
# Elapsed: 59.4551317691803

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model6 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model6.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model6.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_18 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 10)             │         1,290 │
# ...

# %%
import time

start = time.time()

history6 = model6.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model6.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9362 - loss: 0.2075 - val_accuracy: 0.9715 - val_loss: 0.0974
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9721 - loss: 0.0904 - val_accuracy: 0.9752 - val_loss: 0.0877
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9802 - loss: 0.0626 - val_accuracy: 0.9760 - val_loss: 0.0851
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9848 - loss: 0.0510 - val_accuracy: 0.9807 - val_loss: 0.0693
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9872 - loss: 0.0415 - val_accuracy: 0.9805 - val_loss: 0.0752
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9796 - loss: 0.0755
# Test Loss: 0.07551892846822739
# Test Accuracy: 0.9796000123023987
# Elapsed: 59.69306182861328

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model7 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model7.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model7.summary()

import time

start = time.time()

history7 = model7.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model7.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_22 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 10)             │         2,570 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model8 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model8.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model8.summary()

import time

start = time.time()

history8 = model8.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model8.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_23 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 128)            │        32,896 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model9 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model9.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model9.summary()

import time

start = time.time()

history9 = model9.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model9.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_24 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 128)            │        32,896 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model10 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model10.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model10.summary()

import time

start = time.time()

history10 = model10.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model10.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_34 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 10)             │           330 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model11 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model11.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model11.summary()

import time

start = time.time()

history11 = model11.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model11.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_35 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_84 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_85 (Dense)                │ (None, 16)             │           528 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model12 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model12.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model12.summary()

import time

start = time.time()

history12 = model12.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model12.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_36 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 16)             │           528 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model13 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model13.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model13.summary()

import time

start = time.time()

history13 = model13.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model13.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_37"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_37 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_91 (Dense)                │ (None, 16)             │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 16)             │           272 │
# ...

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model14 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model14.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model14.summary()

import time

start = time.time()

history14 = model14.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model14.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_38"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_38 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 16)             │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 10)             │           170 │
# ...

# %% [markdown]
# ### Step 4
# Change epochs (try 3, then 10, then 25) with your best architecture and log each result.

# %%
import time

start = time.time()

history6 = model6.fit(X_train, y_train, epochs=3, validation_split=0.1)
test_loss, test_accuracy = model6.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9896 - loss: 0.0330 - val_accuracy: 0.9817 - val_loss: 0.0772
# Epoch 2/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9916 - loss: 0.0273 - val_accuracy: 0.9805 - val_loss: 0.0856
# Epoch 3/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9917 - loss: 0.0265 - val_accuracy: 0.9807 - val_loss: 0.0875
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.0874
# Test Loss: 0.08738534897565842
# Test Accuracy: 0.9771999716758728
# Elapsed: 44.374449253082275

# %%
import time

start = time.time()

history6 = model6.fit(X_train, y_train, epochs=10, validation_split=0.1)
test_loss, test_accuracy = model6.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9930 - loss: 0.0235 - val_accuracy: 0.9793 - val_loss: 0.0924
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9943 - loss: 0.0191 - val_accuracy: 0.9770 - val_loss: 0.1084
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9940 - loss: 0.0199 - val_accuracy: 0.9842 - val_loss: 0.0828
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9946 - loss: 0.0196 - val_accuracy: 0.9838 - val_loss: 0.0770
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9944 - loss: 0.0186 - val_accuracy: 0.9823 - val_loss: 0.0952
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9827 - val_loss: 0.1074
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9952 - loss: 0.0177 - val_accuracy: 0.9760 - val_loss: 0.1342
# Epoch 8/10
# ...

# %%
import time

start = time.time()

history6 = model6.fit(X_train, y_train, epochs=25, validation_split=0.1)
test_loss, test_accuracy = model6.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9965 - loss: 0.0133 - val_accuracy: 0.9830 - val_loss: 0.0932
# Epoch 2/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9965 - loss: 0.0115 - val_accuracy: 0.9827 - val_loss: 0.1058
# Epoch 3/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9968 - loss: 0.0126 - val_accuracy: 0.9802 - val_loss: 0.1245
# Epoch 4/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9966 - loss: 0.0124 - val_accuracy: 0.9820 - val_loss: 0.1123
# Epoch 5/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9972 - loss: 0.0113 - val_accuracy: 0.9813 - val_loss: 0.1126
# Epoch 6/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 0.9787 - val_loss: 0.1449
# Epoch 7/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9970 - loss: 0.0118 - val_accuracy: 0.9795 - val_loss: 0.1337
# Epoch 8/25
# ...

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Find the SMALLEST network (fewest neurons and layers) that still scores above 95% accuracy — smaller and faster is a real engineering win.

# %%
import time

start = time.time()

history12 = model12.fit(X_train, y_train, epochs=3, validation_split=0.1)
test_loss, test_accuracy = model12.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9680 - loss: 0.1082 - val_accuracy: 0.9677 - val_loss: 0.1190
# Epoch 2/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9714 - loss: 0.0969 - val_accuracy: 0.9673 - val_loss: 0.1244
# Epoch 3/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9729 - loss: 0.0889 - val_accuracy: 0.9628 - val_loss: 0.1378
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9565 - loss: 0.1515
# Test Loss: 0.1514745056629181
# Test Accuracy: 0.9564999938011169
# Elapsed: 9.681464195251465

# %%
import time

start = time.time()

history12 = model12.fit(X_train, y_train, epochs=10, validation_split=0.1)
test_loss, test_accuracy = model12.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9745 - loss: 0.0813 - val_accuracy: 0.9665 - val_loss: 0.1296
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9768 - loss: 0.0770 - val_accuracy: 0.9682 - val_loss: 0.1216
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9787 - loss: 0.0685 - val_accuracy: 0.9692 - val_loss: 0.1214
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9794 - loss: 0.0674 - val_accuracy: 0.9697 - val_loss: 0.1216
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9814 - loss: 0.0618 - val_accuracy: 0.9670 - val_loss: 0.1342
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9812 - loss: 0.0599 - val_accuracy: 0.9665 - val_loss: 0.1278
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9828 - loss: 0.0551 - val_accuracy: 0.9660 - val_loss: 0.1349
# Epoch 8/10
# ...

# %%
import time

start = time.time()

history12 = model12.fit(X_train, y_train, epochs=25, validation_split=0.1)
test_loss, test_accuracy = model12.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9850 - loss: 0.0470 - val_accuracy: 0.9670 - val_loss: 0.1550
# Epoch 2/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9861 - loss: 0.0430 - val_accuracy: 0.9658 - val_loss: 0.1534
# Epoch 3/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9865 - loss: 0.0415 - val_accuracy: 0.9635 - val_loss: 0.1559
# Epoch 4/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9867 - loss: 0.0395 - val_accuracy: 0.9680 - val_loss: 0.1473
# Epoch 5/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9881 - loss: 0.0380 - val_accuracy: 0.9683 - val_loss: 0.1481
# Epoch 6/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9876 - loss: 0.0369 - val_accuracy: 0.9687 - val_loss: 0.1510
# Epoch 7/25
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9886 - loss: 0.0337 - val_accuracy: 0.9678 - val_loss: 0.1603
# Epoch 8/25
# ...

# %%
import time

start = time.time()

history14 = model14.fit(X_train, y_train, epochs=3, validation_split=0.1)
test_loss, test_accuracy = model14.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9429 - loss: 0.1928 - val_accuracy: 0.9508 - val_loss: 0.1632
# Epoch 2/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9466 - loss: 0.1808 - val_accuracy: 0.9542 - val_loss: 0.1517
# Epoch 3/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9483 - loss: 0.1702 - val_accuracy: 0.9540 - val_loss: 0.1550
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9416 - loss: 0.1980
# Test Loss: 0.19800545275211334
# Test Accuracy: 0.9416000247001648
# Elapsed: 8.562984466552734

# %%
import time

start = time.time()

history14 = model14.fit(X_train, y_train, epochs=5, validation_split=0.1)
test_loss, test_accuracy = model14.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9511 - loss: 0.1621 - val_accuracy: 0.9513 - val_loss: 0.1558
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9536 - loss: 0.1551 - val_accuracy: 0.9440 - val_loss: 0.1781
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9555 - loss: 0.1497 - val_accuracy: 0.9573 - val_loss: 0.1439
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9566 - loss: 0.1449 - val_accuracy: 0.9562 - val_loss: 0.1522
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.9587 - loss: 0.1383 - val_accuracy: 0.9550 - val_loss: 0.1607
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9460 - loss: 0.1880
# Test Loss: 0.18801571428775787
# Test Accuracy: 0.9459999799728394
# Elapsed: 15.51632571220398

# %%
import time

start = time.time()

history14 = model14.fit(X_train, y_train, epochs=25, validation_split=0.1)
test_loss, test_accuracy = model14.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)

# %% [markdown]
# best model, fastest, fewest layers/neurons

# %%
import tensorflow as tf

# Load the MNIST handwritten digits dataset — 10 classes (0-9)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0   # normalize pixel values to 0-1

model12 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model12.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model12.summary()

import time

start = time.time()

history12 = model12.fit(X_train, y_train, epochs=3, validation_split=0.1)
test_loss, test_accuracy = model12.evaluate(X_test, y_test)

elapsed = time.time() - start

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Elapsed:", elapsed)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_39"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_39 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 16)             │           528 │
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history12.history['accuracy'], label = 'train accuracy')
plt.plot(history12.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(history12.history['loss'], label = 'loss')
plt.plot(history12.history['val_loss'], label = 'val loss')
plt.xlabel('Epochs')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Project Work: Apply a Neural Network

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
# Compare architectures systematically
for units in [16, 128, 512]:
    m = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    m.fit(X_train, y_train, epochs=3, verbose=0)
    print(units, "neurons ->", m.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# 16 neurons -> 0.9350000023841858
# 128 neurons -> 0.9747999906539917
# 512 neurons -> 0.9786999821662903

# %% [markdown]
# *Switch to your own team's project dataset.*

# %% [markdown]
# ### Step 1
# Adapt today's architecture to your project's features and label. Compile the model.

# %%
# YOUR TURN — Step 1

# %% [markdown]
# ### Step 2
# Train it and print an accuracy or loss number — this is Milestone 3. The bar is intentionally low: the goal is momentum, not perfection.

# %%
# YOUR TURN — Step 2

# %% [markdown]
# ### Step 3
# Plot training vs validation accuracy for your project model, same as this morning.

# %%
# YOUR TURN — Step 3

# %% [markdown]
# ### Step 4
# Try changing ONE architecture choice (neurons, layers, or epochs) and note whether it helped.

# %%
# YOUR TURN — Step 4

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Compare your neural network's accuracy to yesterday's baseline Decision Tree accuracy on the same project data — which won, and why might that be?

# %%
# YOUR TURN — Bonus 1
