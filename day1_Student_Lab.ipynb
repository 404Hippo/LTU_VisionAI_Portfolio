# %% [markdown]
# # DAY 1 — MONDAY — Student Lab Notebook
# ## Python Foundations + What AI, ML, DL & CV Actually Are
#
# **How this notebook works:** every section has a working example — run it first. Then work through each numbered **STEP** in order with your pair; both people should be able to explain every line before moving on. Finished early? Try the **BONUS** challenges.

# %% [markdown]
# ---
# ## Lab: Python Fundamentals Practice

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
scores.append(100)
print(scores)

print(scores[1:3])     # slice: index 1 up to (not including) 3

scores.remove(79)
print(scores)

print(95 in scores)    # membership check

# %% [markdown]
# *Work with your pair. Run every working example first, then complete each step yourselves — both partners should be able to explain every line before moving on.*

# %% [markdown]
# ### Step 1
# Create four variables about yourself — name, age, favorite_number, and is_camper (True/False). Print one full sentence using an f-string that includes all four.

# %%
# YOUR TURN — Step 1
name = "Edward"
age = 15
favorite_animal = "Hippo"
favorite_color = "Black"
favorite_number = "10 or 23"
is_camper = False

print(f"My name is {name} and I am {age} years old. My favorite animal is a {favorite_animal} and my favorite color is {favorite_color}. My status as a camper is {is_camper} and my favorite number is {favorite_number}.")
# Out:
# My name is Edward and I am 15 years old. My favorite animal is a Hippo and my favorite color is Black. My status as a camper is False and my favorite number is 10 or 23.

# %% [markdown]
# ### Step 2
# Build a list of your 5 favorite animes. Print the first item, the last item (using -1), and the list's length.

# %%
# YOUR TURN — Step 2
favorite_animes = ["JJBA", "AOT", "JJK", "Gundam", "CSM"]
print(favorite_animes[0])
print(favorite_animes[-1])
print(len(favorite_animes))
# Out:
# JJBA
# CSM
# 5

# %% [markdown]
# ### Step 3
# Add 2 more foods with .append(). Then remove one you no longer want with .remove(). Print the final list.

# %%
# YOUR TURN — Step 3
favorite_animes.append("Blue Lock")
favorite_animes.append("Demon Slayer")
favorite_animes.remove("CSM")
print(favorite_animes)
# Out:
# ['JJBA', 'AOT', 'JJK', 'Gundam', 'Blue Lock', 'Demon Slayer']

# %% [markdown]
# ### Step 4
# Use type() on three different variables you created this morning and print what type each one is. Were any results surprising?

# %%
# YOUR TURN — Step 4
print(type(favorite_animes))
print(type(age))
print(type(name))
# Out:
# <class 'list'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Use slicing to print just the middle 3 items of a 6-item list you create.
#
# **Bonus 2:** Create a list of 5 numbers. Before running anything, predict on paper what sum(your_list) and max(your_list) will return — then check yourself.

# %%
# YOUR TURN — Bonus 1
print(favorite_animes[2:5])
# Out:
# ['JJK', 'Gundam', 'Blue Lock']

# %%
# YOUR TURN — Bonus 2
numbers = [69, 67, 23, 10, 9]
# sum(numbers) = 178
# max(numbers) = 69

print(sum(numbers))
print(max(numbers))
# Out:
# 178
# 69

# %% [markdown]
# ---
# ## Team Formation + Project Canvas

# %% [markdown]
# **Working example — run this first, then modify it below:**

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

x, y = load_iris(return_X_y=True)
model = DecisionTreeClassifier()
model.fit(x, y)

# Try your own flower measurements!
prediction = model.predict([[5.1, 3.5, 1.4, 0.2]])
print("Predicted species:", prediction)
# Out:
# Predicted species: [0]

# %%
import pandas as pd
from sklearn.datasets import load_iris

data = load_iris(as_frame=True)
df = data.frame
print(df.head())
print(df.shape)
print(df.columns)
print(df.describe)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# (150, 5)
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')
# <bound method NDFrame.describe of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# ...

# %% [markdown]
# *Form teams of 3. Discuss which of the 5 projects excites your team most, and agree on one together.*

# %% [markdown]
# ### Step 1
# Write your team name and chosen project at the top of your Project Canvas worksheet.

# %%
# YOUR TURN — Step 1

# %% [markdown]
# ### Step 2
# In 2-3 sentences, describe what your finished project will DO — what question will it answer, what will the live demo look like on Friday's showcase?

# %%
# YOUR TURN — Step 2

# %% [markdown]
# ### Step 3
# List what you already know about your dataset's topic, and one question you're curious to find the answer to.

# %%
# YOUR TURN — Step 3

# %% [markdown]
# ### Step 4
# Submit Milestone 1 — team name, project choice, and a one-sentence goal — to the instructor.

# %%
# YOUR TURN — Step 4

# %% [markdown]
# ### 🚀 Bonus Challenges — if you finish early
# **Bonus 1:** Sketch what you think your live demo screen will look like on presentation day.

# %%
# YOUR TURN — Bonus 1
